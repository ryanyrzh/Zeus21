# %%
import numpy as np
import matplotlib.pyplot as plt
import zeus21
from scipy.integrate import simpson
from scipy.special import i0
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from zeus21.cosmology import Ddot

import plotly.io as pio
pio.renderers.default = "notebook"

plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=12)

# %%
UserParams = zeus21.User_Parameters(precisionboost=2)
CosmoParams_input = zeus21.Cosmo_Parameters_Input(kmax_CLASS=1000., USE_RELATIVE_VELOCITIES=True)
ClassyCosmo = zeus21.runclass(CosmoParams_input)
CosmoParams = zeus21.Cosmo_Parameters(UserParams, CosmoParams_input, ClassyCosmo) 
CorrFClass = zeus21.Correlations(UserParams, CosmoParams, ClassyCosmo)

# %%
idx_smooth = 30
CosmoParams._Rtabsmoo[idx_smooth] # approx 8 Mpc
# Out:
# np.float64(8.187428672251672)

# %%
CF_v = CorrFClass.xi_RR_CF_v
CF_para = CorrFClass.xi_RR_CF_para
CF_perp = CorrFClass.xi_RR_CF_perp
r_list = CorrFClass.rlist_CF
sigma_v = CorrFClass.sigma_v[0, 0] # No smoothing

CF_v = CF_v[0, 0, :] # No smoothing
CF_para = CF_para[0, 0, :] # No smoothing
CF_perp = CF_perp[0, 0, :] # No smoothing

vbarsq = sigma_v**2
rho_para = CF_para / vbarsq
rho_perp = CF_perp / vbarsq

# %%
rho_para = rho_para[16:]
rho_perp = rho_perp[16:]

# %%
def prefactor_N(vbarsq, rho_para, rho_perp):
    return (2 * np.pi)**3 * vbarsq * np.sqrt(1 - rho_para**2) * (1 - rho_perp**2)

def P_v_v(vbarsq, rho_para, rho_perp, v_1_z, v_1_perp, v_2_z, v_2_perp):
    '''
    Joint PDF of velocities v_1 and v_2.
    The last dimensions of v_1_perp and v_2_perp must have length 2.
    Not currently used
    TODO: Fix dimensional problem
    '''
    N = prefactor_N(vbarsq, rho_para, rho_perp)
    exponent = - 1 / (2 * vbarsq) * (
                                    (v_1_z**2 + v_2_z**2 - 2 * rho_para * v_1_z * v_2_z) / (1 - rho_para**2) + 
                                    (v_1_perp**2 + v_2_perp**2 - 2 * rho_perp * np.inner(v_1_perp, v_2_perp)) / (1 - rho_perp**2)
                                    )
    return 1 / N * np.exp(exponent)

def P_X_Y(X, Y, vbarsq, rho_para, rho_perp, n_points=100):
    '''
    Joint PDF of X=v_1**2 and Y=v_2**2.
    rho_para and rho_perp must have the same length (currently only support 1 dimension)
    '''
    rho_para = np.array([rho_para]) if np.isscalar(rho_para) else np.array(rho_para)
    rho_perp = np.array([rho_perp]) if np.isscalar(rho_perp) else np.array(rho_perp)
    X = np.array([X]) if np.isscalar(X) else np.array(X)
    Y = np.array([Y]) if np.isscalar(Y) else np.array(Y)

    vbarsq = np.full_like(rho_para, vbarsq) # currently limited to scalar value vbarsq

    sqrtX = np.sqrt(X)
    sqrtY = np.sqrt(Y)

    # n_r is the length of r_list, vbarsq, rho_para, and rho_perp
    n_r, n_X, n_Y = len(vbarsq), len(X), len(Y)

    result = np.zeros((n_r, n_X, n_Y))

    # Loop over X and Y (needed due to different integration bounds)
    # But vectorize over r dimension
    for j in range(len(X)):
        for k in range(len(Y)):
            v_1_z_arr = np.linspace(-0.999*sqrtX[j], 0.999*sqrtX[j], n_points)
            v_2_z_arr = np.linspace(-0.999*sqrtY[k], 0.999*sqrtY[k], n_points)

            v_1_z_mesh, v_2_z_mesh = np.meshgrid(v_1_z_arr, v_2_z_arr, indexing='ij')
            X_arr = np.full_like(v_1_z_mesh, X[j])
            Y_arr = np.full_like(v_2_z_mesh, Y[k])

            # Broadcast to shape: (n_r, n_points, n_points)
            vbarsq_grid = vbarsq[:, np.newaxis, np.newaxis]
            rho_para_grid = rho_para[:, np.newaxis, np.newaxis]
            rho_perp_grid = rho_perp[:, np.newaxis, np.newaxis]
            v_1_z_grid = v_1_z_mesh[np.newaxis, :, :]
            v_2_z_grid = v_2_z_mesh[np.newaxis, :, :]
            X_grid = X_arr[np.newaxis, :, :]
            Y_grid = Y_arr[np.newaxis, :, :]

            # Compute prefactor
            N = prefactor_N(vbarsq, rho_para, rho_perp)
            prefactor = np.pi / N * np.exp(- (X[j] + Y[k]) / (2 * vbarsq * (1 - rho_perp**2)))

            # Compute integrand
            integrand_exp = - 1 / (2 * vbarsq_grid) * (
                                        (rho_para_grid**2 - rho_perp_grid**2) * (v_1_z_grid**2 + v_2_z_grid**2) / ((1 - rho_para_grid**2) * (1 - rho_perp_grid**2)) - 
                                        2 * rho_para_grid * v_1_z_grid * v_2_z_grid / (1 - rho_para_grid**2)
                                        )
            argument = rho_perp_grid * np.sqrt(X_grid - v_1_z_grid**2) * np.sqrt(Y_grid - v_2_z_grid**2) / (vbarsq_grid * (1 - rho_perp_grid**2))
            integrand_I0 = i0(argument)

            # Integrate
            integral_v2 = simpson(integrand_exp * integrand_I0, x=v_2_z_arr)
            integral_v1_v2 = simpson(integral_v2, x=v_1_z_arr)

            result[:, j, k] = prefactor * integral_v1_v2

    return result

# %%
X_arr = np.geomspace(100, 1e6, 30)
Y_arr = np.geomspace(100, 1e6, 30)

P_X_Y_arr = P_X_Y(X_arr, Y_arr, vbarsq, rho_para, rho_perp)

# %%
fig = go.Figure()

# Add surfaces for each r value (first index)
n_r = P_X_Y_arr.shape[0]
for i in range(n_r):
    fig.add_trace(
        go.Surface(
            z=P_X_Y_arr[i, :, :],
            x=X_arr,
            y=Y_arr,
            visible=(i == n_r-1),  # Only show the last one initially
            name=f'r = {r_list[16+i]:.1f} Mpc/h'
        )
    )

# Create slider steps
steps = []
for i in range(n_r):
    step = dict(
        method="update",
        args=[{"visible": [False] * n_r}],  # Hide all traces
        label=f'{r_list[16+i]:.1f}'
    )
    step["args"][0]["visible"][i] = True  # Show only the i-th trace
    steps.append(step)

# Add slider
sliders = [dict(
    active=n_r-1,  # Start with the last index
    currentvalue={"prefix": "r = ", "suffix": " Mpc/h"},
    pad={"t": 50},
    steps=steps
)]

fig.update_layout(
    title='Joint PDF for velocity² with anisotropic correlations',
    scene=dict(
        xaxis_title='X= v₁²[km²h⁻²s⁻²]',
        yaxis_title='Y= v₂²[km²h⁻²s⁻²]',
        zaxis_title='P(X, Y)'
    ),
    sliders=sliders
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="3f1afa29-eb10-4719-8542-7c45c0701c96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3f1afa29-eb10-4719-8542-7c45c0701c96")) {                    Plotly.newPlot(                        "3f1afa29-eb10-4719-8542-7c45c0701c96",                        [{"name":"r = 2.2 Mpc\u002fh","visible":false,"x":{"dtype":"f8","bdata":"AAAAAAAAWUCdUB50PCxhQOYZdWGnl2dAjd6Hx7U0cECDw2C8mEN2QFEI89A9ln5A0Q+cn68ChUDlgF\u002fqXd2MQFDmNhHY05NAlEzEtlA9m0BYjyKhDbaiQK+weGqwtKlAQSU5iVqosUDlvQlfK0K4QN9N4dnWqcBAxxPb8ILkxkBs8DBlT3PPQAAFIW2KmtVAeS1wC\u002f2t3UCGdEgPJmPkQLvsp80wAuxA8gnuDEo980A83zHGem76QL3ekq\u002f5JwJB8pM3xn\u002fxCEF2mEh7RiIRQTiMICv4iRdBrwqaYU8rIEEc28\u002fErjYmQQAAAACAhC5B"},"y":{"dtype":"f8","bdata":"AAAAAAAAWUCdUB50PCxhQOYZdWGnl2dAjd6Hx7U0cECDw2C8mEN2QFEI89A9ln5A0Q+cn68ChUDlgF\u002fqXd2MQFDmNhHY05NAlEzEtlA9m0BYjyKhDbaiQK+weGqwtKlAQSU5iVqosUDlvQlfK0K4QN9N4dnWqcBAxxPb8ILkxkBs8DBlT3PPQAAFIW2KmtVAeS1wC\u002f2t3UCGdEgPJmPkQLvsp80wAuxA8gnuDEo980A83zHGem76QL3ekq\u002f5JwJB8pM3xn\u002fxCEF2mEh7RiIRQTiMICv4iRdBrwqaYU8rIEEc28\u002fErjYmQQAAAACAhC5B"},"z":{"dtype":"f8","bdata":"UnbiSVA+SD5XxkBZxdtQPv8c+7dmBlg+pfy94bKCYT5DmQsOgQpqPh8nSkfusXM+v7WBTro0fj7+L4KIf2qHPu3cxOMoTZI+kkYrZHzGnD5maCrULLWmPlGo4dJr9LE+LRjxqnFmvD5kR6TPXm3GPmwfRUpHptE+HqH19bae2z5fnKnu5mzlPui8Mp82avA+jT+tvHW3+D46Sb6daykCP0sWQCkRzwk\u002f+6RmYg6CET9p4YboikkWP\u002f9J40CR\u002fRk\u002fY+vObYbeGj\u002fxL5SmMIoXPzBruFVnbRA\u002fb8eosDPGAD9Xrizmh0zmPrksvpk0b8A+V8ZAWcXbUD4KgIGiYt1WPgO15FDLy18+Z6fMqB6nZj4vhuXOx4FwPrcp8mycing+Mau+mLSNgj4BjZ45lHCMPr44z8DDB5Y+sHmo02AzoT6EYue\u002fqgGrPgYxD7VCRbU+Wjki\u002fwzGwD6Qj3AyVW\u002fKPut\u002fjfE+xdQ+EmUrVa074D6+Fc9MzSnpPqEUqm9DRPM+NNoX8lv\u002f\u002fD5XdlY\u002f40wFP48EB6X7Qg4\u002fBM0rlnCGFD+XEzij8h8aPy68bwuLdh4\u002fbCmwyMF9Hz+9attZkZYbP0Ri31qTQBM\u002fEII\u002fNqqoAz\u002foLo1dXSLqPoqgaBYJQ8M+AR37t2YGWD4DteRQy8tfPn06QjNMj2U+4yCjrgj6bT7hRIgLJVp1Po2GvBD9G38+uaWamNEdhz7XG2ehe3eRPs+DCXH6wJo+okQ4KfuzpD6na4JCPiSwPqhwJm1iS7k+m4Kmq3zewz77Us4F7TjPPveoc3O6etg+UXhHMP0Z4z5jcqvWQ5PtPitb1UYfoPY+6vtg1woEAT88N\u002fk9o\u002fwIP6ye\u002f3ZmvhE\u002f76KbJF4QGD8QAMQhtp8eP0zWGNI\u002f2iE\u002fa9BI4SJ0Ij+Z3LNnbSogP4twJzjZjxY\u002fVlftoN0JBz\u002f6prkzzKDuPpwTusBKk8Y+pPy94bKCYT5op8yoHqdmPuMgo64I+m0+iFw63a9SdD4sEUZ9TEB8Pi3fY6UDHoQ+p1VJMmxMjT4OQ7QbUsKVPrfpPiLEbaA+X8yTIlwjqT7487o\u002f4WyzPlmY3TJkO74+ZnEXnNGfxz60fEZPQ33SPtQvcSCK6Nw+did7E0+C5j7+bEuu42XxPoMEB2eplvo+G7rxerH6Az8ULxfmB1INPzroq77PzxQ\u002f5lIpVDI3HD+ZNPN8E\u002fMhP8YMdvCk7CQ\u002fyY0prGugJT8L5GU7svEiP8i5T5RccBo\u002fQZzLmmb\u002fCj+XJmHdTvLxPvbHYLlMdco+Q5kLDoEKaj4uhuXOx4FwPuFEiAslWnU+KxFGfUxAfD6PF0OwLSaDPjvYlNuXnIo+Yq+NpTnxkj7gEqLqgpKbPnDXueQ0dqQ+M2i+ZeTdrj4IQUvH65S3PvM4uGXyL8I+zW0xjdo6zD6FFZ6xqfrVPhM3RDCNHeE+jfRn0nKT6j6RHyE7VX\u002f0PtNMmj2RRv8+0uhMEFx5Bz8y7yixwzURP9Cd4vKcahg\u002fe3ZkiUOLID\u002fMAahh3golPxYXnFRIhig\u002fHSuUvQpYKT+SCNGcyTImP7tPmUbC+h4\u002fuFnIpnOiDz8WdEjStQf1PoajKK3\u002fAc8+HydKR+6xcz62KfJsnIp4Po2GvBD9G38+Ld9jpQMehD472JTbl5yKPjmnv9BcCJI+CpvRrNkMmT72mn2tM9KhPgWrh1bB66k+w\u002fZKV2o3sz4khkxfhfK8Prrlf52MEsY+tVD8Y1z60D68+D6kqkHaPlyg4BUUV+Q+om7XG8l17z5gxp5ZrDH4PlMA5wwhawI\u002fz6NR2b+aCz\u002f4bju+ATcUPzB1r7TKpxw\u002fukDgI4lnIz\u002fyiJWmg6soP1SOyq5gviw\u002fU3Bc+7KyLT9jFrvOTgIqPxFk0PTaJSI\u002f2g7ZSimIEj+XJeAaL6T4PvzlR0hEK9I+v7WBTro0fj4xq76YtI2CPrilmpjRHYc+pVVJMmxMjT5ir42lOfGSPgub0azZDJk+cBR0KcT3oD4fptsT446nPoEKW2NCv7A+KaQG5HFVuD5Fpcm0rgPCPj9L\u002fll\u002fFcs+YYaS4r+Y1D6xdV394ZHfPp7Dv3L8Seg+3TyObLqv8j7+Q5CRGKH8Pp3\u002f9lRXuwU\u002fRkw6DxNAED8W2nwATMMXP0rJnBm40iA\u002fBKRxkt7DJj8KysiM6ewsP66\u002fU3EM2D ...
